# %% [markdown]
# <a href="https://colab.research.google.com/github/zohai-ibb/AI-Image-Generator/blob/main/Practice_of_task_session_16_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
pd.Series(dtype="int64")
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here

series1 = pd.Series([2, 4, 6, 8, 10])
series2 = pd.Series([1, 3, 5, 7, 10])
print(series1)
print(series2)

print(series1 + series2, series1 - series2, series1 * series2, series1 / series2)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# 0     1
# 1     3
# 2     5
# 3     7
# 4    10
# dtype: int64
# 0     3
# 1     7
# 2    11
# 3    15
# 4    20
# dtype: int64 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# dtype: int64 0      2
# 1     12
# 2     30
# 3     56
# 4    100
# dtype: int64 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.000000
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
s1 = pd.Series([2, 4, 6, 8, 10])
s2 = pd.Series([1, 3, 5, 7, 10])

s1 == s2
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
def func(series, dtype):
  return series.astype(dtype)

series = pd.Series([1,2,'Python', 2.0, True, 100])
print(func(series, str))
# Out:
# 0         1
# 1         2
# 2    Python
# 3       2.0
# 4      True
# 5       100
# dtype: object

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
s1 = pd.read_csv("/content/batsman_runs_series.csv",  index_col="batter").squeeze("columns")
s1.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here

s1[s1 > 3000].size
# Out:
# 20

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here

s1[s1 > s1.mean()].size
# Out:
# 128

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %%
items = pd.read_csv("/content/items.csv", index_col="item_name").squeeze("columns")

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here
#ii. Show no of nan values
items[items.isnull()].size
# Out:
# 50

# %%
#ii. Item price is given in $, so convert it to rupees without currency symbol.
items.values
type(items.values[0])
new = items.apply(lambda x: float(str(x).replace('$',""))*85)

# %%
#iv. Fill nan with mean of the series
new.mean()
new.fillna(new.mean())
# Out:
# item_name
# Chips and Fresh Tomato Salsa              203.15
# Izze                                      288.15
# Nantucket Nectar                          288.15
# Chips and Tomatillo-Green Chili Salsa     203.15
# Chicken Bowl                             1443.30
#                                           ...
# Steak Burrito                             998.75
# Steak Burrito                             998.75
# Chicken Salad Bowl                        956.25
# Chicken Salad Bowl                        743.75
# Chicken Salad Bowl                        743.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here
new.mean()
# Out:
# np.float64(634.3576771653543)

# %%
new[new.between(1000, 2000)].size
# Out:
# 142

# %%
#Plot Histogram on price with bin size 50
new.plot()
# Out:
# <Axes: xlabel='item_name'>
